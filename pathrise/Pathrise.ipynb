# %% [markdown]
# <a href="https://colab.research.google.com/github/somayeh-najafi/datasciense/blob/main/pathrise/Pathrise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4be4bb29-f4b1-44b6-9416-ecfa99f66a25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4be4bb29-f4b1-44b6-9416-ecfa99f66a25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('pathrise-data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2544 entries, 0 to 2543
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           2544 non-null   int64
#  1   pathrise_status              2544 non-null   object
#  2   primary_track                2544 non-null   object
#  3   cohort_tag                   2536 non-null   object
#  4   program_duration_days        1928 non-null   float64
#  5   placed                       2544 non-null   int64
#  6   employment_status            2315 non-null   object
#  7   highest_level_of_education   2486 non-null   object
#  8   length_of_job_search         2470 non-null   object
#  9   biggest_challenge_in_search  2520 non-null   object
#  10  professional_experience      2322 non-null   object
#  11  work_authorization_status    2260 non-null   object
#  12  number_of_interviews         2326 non-null   float64
# ...

# %%
df = df[df['pathrise_status'].isin (["Placed","Withdrawn (Failed)"])]

# %%
df['pathrise_status']
# Out:
# 4                   Placed
# 7       Withdrawn (Failed)
# 23                  Placed
# 30                  Placed
# 39                  Placed
#                ...
# 2531                Placed
# 2533                Placed
# 2534                Placed
# 2539    Withdrawn (Failed)
# 2540    Withdrawn (Failed)
# Name: pathrise_status, Length: 1038, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1038 entries, 4 to 2540
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           1038 non-null   int64
#  1   pathrise_status              1038 non-null   object
#  2   primary_track                1038 non-null   object
#  3   program_duration_days        1038 non-null   float64
#  4   placed                       1038 non-null   int64
#  5   employment_status            1038 non-null   object
#  6   highest_level_of_education   1020 non-null   object
#  7   length_of_job_search         998 non-null    object
#  8   biggest_challenge_in_search  1023 non-null   object
#  9   professional_experience      974 non-null    object
#  10  work_authorization_status    900 non-null    object
#  11  number_of_interviews         947 non-null    float64
#  12  number_of_applications       1038 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'pathrise_status', 'primary_track', 'cohort_tag',
#        'program_duration_days', 'placed', 'employment_status ',
#        'highest_level_of_education', 'length_of_job_search',
#        'biggest_challenge_in_search', 'professional_experience',
#        'work_authorization_status', 'number_of_interviews',
#        'number_of_applications', 'gender', 'race'],
#       dtype='object')

# %%
df.drop(columns=['cohort_tag','race','gender'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-0e68b60bfb9a> in <cell line: 1>()
# ----> 1 df.drop(columns=['cohort_tag','race','gender'],inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
df
# Out:
#         id     pathrise_status primary_track  program_duration_days  placed  \
# 4        5              Placed           SWE                   89.0       1
# 7        8  Withdrawn (Failed)           SWE                   19.0       0
# 23      24              Placed           PSO                  193.0       1
# 30      31              Placed           SWE                   73.0       1
# 39      40              Placed           SWE                   83.0       1
# ...    ...                 ...           ...                    ...     ...
# 2531  2532              Placed           SWE                  310.0       1
# 2533  2534              Placed        Design                   33.0       1
# 2534  2535              Placed           SWE                  119.0       1
# 2539  2540  Withdrawn (Failed)        Design                  457.0       0
# 2540  2541  Withdrawn (Failed)          Data                  488.0       0
#
# ...

# %%
df['program_duration_days']
# Out:
# 4        89.0
# 7        19.0
# 23      193.0
# 30       73.0
# 39       83.0
#         ...
# 2531    310.0
# 2533     33.0
# 2534    119.0
# 2539    457.0
# 2540    488.0
# Name: program_duration_days, Length: 1038, dtype: float64

# %%
df.columns = df.columns.str.rstrip()

# %%
df['employment_status'].value_counts()
# Out:
# Student               310
# Unemployed            272
# Employed Full-Time    172
# Employed Part-Time    115
# Contractor             60
# Name: employment_status, dtype: int64

# %%
df['employment_status'].mode()[0]
# Out:
# 'Student'

# %%
df['employment_status'].isnull().sum()
# Out:
# 109

# %%
df['employment_status'].isnull()
# Out:
# 4       False
# 7       False
# 23      False
# 30      False
# 39      False
#         ...
# 2531    False
# 2533     True
# 2534    False
# 2539    False
# 2540     True
# Name: employment_status, Length: 1038, dtype: bool

# %%
df['employment_status'].fillna(df['employment_status'].mode()[0],inplace=True)

# %%
df['highest_level_of_education'].isnull().sum()
# Out:
# 18

# %%
df['highest_level_of_education'].value_counts()
# Out:
# Bachelor's Degree                   573
# Master's Degree                     312
# Doctorate or Professional Degree     64
# Some College, No Degree              52
# High School Graduate                 10
# GED or equivalent                     5
# Some High School                      4
# Name: highest_level_of_education, dtype: int64

# %%
df['highest_level_of_education'].fillna(df['highest_level_of_education'].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1038 entries, 4 to 2540
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           1038 non-null   int64
#  1   pathrise_status              1038 non-null   object
#  2   primary_track                1038 non-null   object
#  3   program_duration_days        1038 non-null   float64
#  4   placed                       1038 non-null   int64
#  5   employment_status            1038 non-null   object
#  6   highest_level_of_education   1038 non-null   object
#  7   length_of_job_search         1038 non-null   object
#  8   biggest_challenge_in_search  1038 non-null   object
#  9   professional_experience      1038 non-null   object
#  10  work_authorization_status    1038 non-null   object
#  11  number_of_interviews         1038 non-null   float64
#  12  number_of_applications       1038 non-null   int64
# ...

# %%
df['length_of_job_search'].fillna(df['length_of_job_search'].mode()[0],inplace=True)

# %%
df['biggest_challenge_in_search'].value_counts()
# Out:
# Hearing back on my applications         382
# Getting past final round interviews     142
# Technical interviewing                  121
# Lack of relevant experience              94
# Getting past mid-stage interviews        87
# Getting past phone screens               77
# Figuring out which jobs to apply for     73
# Behavioral interviewing                  26
# Resume gap                               12
# Technical skills                          9
# Name: biggest_challenge_in_search, dtype: int64

# %%
df['biggest_challenge_in_search'].fillna(df['biggest_challenge_in_search'].mode()[0],inplace=True)

# %%
df['professional_experience'].value_counts()
# Out:
# 1-2 years             355
# Less than one year    264
# 3-4 years             240
# 5+ years              115
# Name: professional_experience, dtype: int64

# %%
df['professional_experience'].isnull().sum()
# Out:
# 64

# %%
df['professional_experience'].fillna(df['professional_experience'].mode()[0],inplace=True)

# %%
df
# Out:
#         id     pathrise_status primary_track  program_duration_days  placed  \
# 4        5              Placed           SWE                   89.0       1
# 7        8  Withdrawn (Failed)           SWE                   19.0       0
# 23      24              Placed           PSO                  193.0       1
# 30      31              Placed           SWE                   73.0       1
# 39      40              Placed           SWE                   83.0       1
# ...    ...                 ...           ...                    ...     ...
# 2531  2532              Placed           SWE                  310.0       1
# 2533  2534              Placed        Design                   33.0       1
# 2534  2535              Placed           SWE                  119.0       1
# 2539  2540  Withdrawn (Failed)        Design                  457.0       0
# 2540  2541  Withdrawn (Failed)          Data                  488.0       0
#
# ...

# %%
df['work_authorization_status'].isnull().sum()
# Out:
# 138

# %%
df['work_authorization_status'].value_counts()
# Out:
# Citizen           440
# F1 Visa/OPT       255
# Green Card         75
# F1 Visa/CPT        54
# Other              46
# H1B                18
# Canada Citizen     10
# STEM OPT            2
# Name: work_authorization_status, dtype: int64

# %%
df['work_authorization_status'].fillna(df['work_authorization_status'].mode()[0],inplace=True)

# %%
df['number_of_interviews'].value_counts()
# Out:
# 0.0     325
# 1.0     190
# 2.0     135
# 4.0      83
# 3.0      74
# 5.0      54
# 6.0      33
# 7.0      25
# 10.0      9
# 20.0      5
# 11.0      4
# 8.0       3
# 19.0      2
# 15.0      1
# 12.0      1
# 14.0      1
# 16.0      1
# 17.0      1
# Name: number_of_interviews, dtype: int64

# %%
df['number_of_interviews'].mean()
# Out:
# 2.140443505807814

# %%
df['number_of_interviews'].mode()
# Out:
# 0    0.0
# Name: number_of_interviews, dtype: float64

# %%
df['number_of_interviews'].isnull().sum()
# Out:
# 0

# %%
df['number_of_interviews'].fillna(df['number_of_interviews'].mean(),inplace=True)

# %%
df['gender'].isnull().sum()
# Out:
# 171

# %%
df['gender'].value_counts()
# Out:
# Male                        660
# Female                      201
# Decline to Self Identify      5
# Non-Binary                    1
# Name: gender, dtype: int64

# %%
df.drop(columns='gender',inplace=True)

# %%
df.info(

)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1038 entries, 4 to 2540
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           1038 non-null   int64
#  1   pathrise_status              1038 non-null   object
#  2   primary_track                1038 non-null   object
#  3   program_duration_days        1038 non-null   float64
#  4   placed                       1038 non-null   int64
#  5   employment_status            1038 non-null   object
#  6   highest_level_of_education   1038 non-null   object
#  7   length_of_job_search         1038 non-null   object
#  8   biggest_challenge_in_search  1038 non-null   object
#  9   professional_experience      1038 non-null   object
#  10  work_authorization_status    1038 non-null   object
#  11  number_of_interviews         1038 non-null   float64
#  12  number_of_applications       1038 non-null   int64
# ...

# %%
df.describe()
# Out:
#                 id  program_duration_days       placed  number_of_interviews  \
# count  1038.000000            1038.000000  1038.000000           1038.000000
# mean   1237.185934             179.911368     0.921002              2.140444
# std     757.116273             121.276328     0.269866              2.699391
# min       5.000000               0.000000     0.000000              0.000000
# 25%     647.250000              82.000000     1.000000              0.000000
# 50%    1259.500000             159.000000     1.000000              2.000000
# 75%    1919.250000             258.000000     1.000000              3.000000
# max    2541.000000             548.000000     1.000000             20.000000
#
#        number_of_applications
# count             1038.000000
# mean                34.123314
# std                 41.313630
# min                  0.000000
# 25%                  8.000000
# 50%                 20.000000
# 75%                 45.000000
# ...

# %%
df[(df['pathrise_status']=="Withdrawn (Failed)") & (df['placed']==1)]
# Out:
# Empty DataFrame
# Columns: [id, pathrise_status, primary_track, program_duration_days, placed, employment_status, highest_level_of_education, length_of_job_search, biggest_challenge_in_search, professional_experience, work_authorization_status, number_of_interviews, number_of_applications]
# Index: []

# %%
df.drop(columns='pathrise_status',inplace=True)

# %%
df
# Out:
#         id primary_track  program_duration_days  placed   employment_status  \
# 4        5           SWE                   89.0       1          Unemployed
# 7        8           SWE                   19.0       0  Employed Part-Time
# 23      24           PSO                  193.0       1          Unemployed
# 30      31           SWE                   73.0       1             Student
# 39      40           SWE                   83.0       1  Employed Full-Time
# ...    ...           ...                    ...     ...                 ...
# 2531  2532           SWE                  310.0       1          Unemployed
# 2533  2534        Design                   33.0       1             Student
# 2534  2535           SWE                  119.0       1  Employed Full-Time
# 2539  2540        Design                  457.0       0          Contractor
# 2540  2541          Data                  488.0       0             Student
#
# ...

# %%
df['number_of_interviews'] = df['number_of_interviews'].astype(int)

# %%
df['program_duration_days'] = df['program_duration_days'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1038 entries, 4 to 2540
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           1038 non-null   int64
#  1   primary_track                1038 non-null   object
#  2   program_duration_days        1038 non-null   int64
#  3   placed                       1038 non-null   int64
#  4   employment_status            1038 non-null   object
#  5   highest_level_of_education   1038 non-null   object
#  6   length_of_job_search         1038 non-null   object
#  7   biggest_challenge_in_search  1038 non-null   object
#  8   professional_experience      1038 non-null   object
#  9   work_authorization_status    1038 non-null   object
#  10  number_of_interviews         1038 non-null   int64
#  11  number_of_applications       1038 non-null   int64
# dtypes: int64(5), object(7)
# memory usage: 105.4+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(x='program_duration_days', data=df)
# Out:
# <Axes: xlabel='program_duration_days', ylabel='Count'>

# %%
sns.displot(data=df,x='program_duration_days')

# %%
sns.displot(x='number_of_interviews',data=df)

# %%
sns.countplot(data=df,x='primary_track')
# Out:
# <Axes: xlabel='primary_track', ylabel='count'>

# %%
sns.countplot(data=df,x='employment_status')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Unemployed'),
#   Text(1, 0, 'Employed Part-Time'),
#   Text(2, 0, 'Student'),
#   Text(3, 0, 'Employed Full-Time'),
#   Text(4, 0, 'Contractor')])

# %%
sns.countplot(data=df,x='highest_level_of_education')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, "Bachelor's Degree"),
#   Text(1, 0, "Master's Degree"),
#   Text(2, 0, 'Some College, No Degree'),
#   Text(3, 0, 'Doctorate or Professional Degree'),
#   Text(4, 0, 'High School Graduate'),
#   Text(5, 0, 'GED or equivalent'),
#   Text(6, 0, 'Some High School')])

# %%
sns.boxplot(x='program_duration_days',y='professional_experience',data=df,hue='placed')
plt.xticks(rotation=90)
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.]),
#  [Text(-100.0, 0, '−100'),
#   Text(0.0, 0, '0'),
#   Text(100.0, 0, '100'),
#   Text(200.0, 0, '200'),
#   Text(300.0, 0, '300'),
#   Text(400.0, 0, '400'),
#   Text(500.0, 0, '500'),
#   Text(600.0, 0, '600')])

# %%
sns.scatterplot(x='program_duration_days',y='professional_experience',data=df,hue='placed')
# Out:
# <Axes: xlabel='program_duration_days', ylabel='professional_experience'>

# %%
df.rename(columns={'highest_level_of_education':'Education','number_of_applications':'Applications','number_of_interviews':'Interviews','professional_experience':'Experience','biggest_challenge_in_search':'Challenge'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1038 entries, 4 to 2540
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1038 non-null   int64
#  1   primary_track              1038 non-null   object
#  2   program_duration_days      1038 non-null   int64
#  3   placed                     1038 non-null   int64
#  4   employment_status          1038 non-null   object
#  5   Education                  1038 non-null   object
#  6   length_of_job_search       1038 non-null   object
#  7   Challenge                  1038 non-null   object
#  8   Experience                 1038 non-null   object
#  9   work_authorization_status  1038 non-null   object
#  10  Interviews                 1038 non-null   int64
#  11  Applications               1038 non-null   int64
# dtypes: int64(5), object(7)
# memory usage: 137.7+ KB

# %%
df
# Out:
#         id primary_track  program_duration_days  placed   employment_status  \
# 4        5           SWE                     89       1          Unemployed
# 7        8           SWE                     19       0  Employed Part-Time
# 23      24           PSO                    193       1          Unemployed
# 30      31           SWE                     73       1             Student
# 39      40           SWE                     83       1  Employed Full-Time
# ...    ...           ...                    ...     ...                 ...
# 2531  2532           SWE                    310       1          Unemployed
# 2533  2534        Design                     33       1             Student
# 2534  2535           SWE                    119       1  Employed Full-Time
# 2539  2540        Design                    457       0          Contractor
# 2540  2541          Data                    488       0             Student
#
# ...

# %%
df['Education'].value_counts()
# Out:
# Bachelor       591
# Master         312
# PHD             64
# College         52
# High School     14
# GED              5
# Name: Education, dtype: int64

# %%
def cleaner(x):
  x = x.replace("Bachelor's Degree",'Bachelor')
  x = x.replace("Master's Degree",'Master')
  x = x.replace('Doctorate or Professional Degree','PHD')
  x = x.replace("Some College, No Degree",'College')
  x = x.replace('High School Graduate','High School')
  x = x.replace('Some High School','High School')
  x = x.replace("GED or equivalent",'GED')
  x = x.replace('Less than one month',"0-1 month")
  x = x.replace('6 months to a year',"6-12 months")
  x = x.replace('Over a yea',">1 year")

  return(x)

# %%
df['Education'] = df['Education'].apply(cleaner)

# %%
df['length_of_job_search'].value_counts()
# Out:
# 1-2 months             378
# Less than one month    324
# 3-5 months             198
# 6 months to a year      93
# Over a year             45
# Name: length_of_job_search, dtype: int64

# %%
df['length_of_job_search'] = df['length_of_job_search'].apply(cleaner)

# %%
df.columns
# Out:
# Index(['id', 'primary_track', 'program_duration_days', 'placed',
#        'employment_status', 'Education', 'length_of_job_search', 'Challenge',
#        'Experience', 'work_authorization_status', 'Interviews',
#        'Applications'],
#       dtype='object')

# %%
df['employment_status'].value_counts()
# Out:
# Student               419
# Unemployed            272
# Employed Full-Time    172
# Employed Part-Time    115
# Contractor             60
# Name: employment_status, dtype: int64

# %%
pd.get_dummies(df,columns=['primary_track','employment_status', 'Education', 'length_of_job_search', 'Challenge',
       'Experience', 'work_authorization_status'])
# Out:
#         id  program_duration_days  placed  Interviews  Applications  \
# 4        5                     89       1          10           100
# 7        8                     19       0           4            15
# 23      24                    193       1           5             4
# 30      31                     73       1           0             1
# 39      40                     83       1           2            15
# ...    ...                    ...     ...         ...           ...
# 2531  2532                    310       1           0             6
# 2533  2534                     33       1           0             9
# 2534  2535                    119       1           0            10
# 2539  2540                    457       0           4            15
# 2540  2541                    488       0           1             7
#
#       primary_track_Data  primary_track_Design  primary_track_Marketing  \
# 4                      0                     0                        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1038 entries, 4 to 2540
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1038 non-null   int64
#  1   primary_track              1038 non-null   object
#  2   program_duration_days      1038 non-null   int64
#  3   placed                     1038 non-null   int64
#  4   employment_status          1038 non-null   object
#  5   Education                  1038 non-null   object
#  6   length_of_job_search       1038 non-null   object
#  7   Challenge                  1038 non-null   object
#  8   Experience                 1038 non-null   object
#  9   work_authorization_status  1038 non-null   object
#  10  Interviews                 1038 non-null   int64
#  11  Applications               1038 non-null   int64
# dtypes: int64(5), object(7)
# memory usage: 137.7+ KB
