# %% [markdown]
# <a href="https://colab.research.google.com/github/somayeh-najafi/datasciense/blob/main/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-97e67909-e544-4245-9fad-97228811ef14" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97e67909-e544-4245-9fad-97228811ef14">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('df.csv')

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5892 entries, 0 to 5891
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5892 non-null   object
#  1   Salary Estimate    5892 non-null   object
#  2   Rating             5892 non-null   float64
#  3   Company Name       5892 non-null   object
#  4   Location           5892 non-null   object
#  5   Size               5892 non-null   object
#  6   Founded            5892 non-null   object
#  7   Type of ownership  5892 non-null   object
#  8   Industry           5892 non-null   object
#  9   Sector             5892 non-null   object
#  10  Revenue            5892 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 506.5+ KB

# %%
df['Salary Estimate']
# Out:
# 0       $111K-$181K (Glassdoor est.)
# 1       $111K-$181K (Glassdoor est.)
# 2       $111K-$181K (Glassdoor est.)
# 3       $111K-$181K (Glassdoor est.)
# 4       $111K-$181K (Glassdoor est.)
#                     ...
# 5887    $42K - $76K (Glassdoor est.)
# 5888                              -1
# 5889                              -1
# 5890                              -1
# 5891              $65 - $72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
def Dollar_remover(a):
  a = a.replace('$','')
  return(a)

# %%
df['Salary Estimate'].apply(Dollar_remover)
# Out:
# 0       111K-181K (Glassdoor est.)
# 1       111K-181K (Glassdoor est.)
# 2       111K-181K (Glassdoor est.)
# 3       111K-181K (Glassdoor est.)
# 4       111K-181K (Glassdoor est.)
#                    ...
# 5887    42K - 76K (Glassdoor est.)
# 5888                            -1
# 5889                            -1
# 5890                            -1
# 5891              65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Salary Estimate'] = df['Salary Estimate'].apply(Dollar_remover)

# %%
df
# Out:
#                                      Job Title             Salary Estimate  \
# 0                        Senior Data Scientist  111K-181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  111K-181K (Glassdoor est.)
# 2                         Data Science Manager  111K-181K (Glassdoor est.)
# 3                                 Data Analyst  111K-181K (Glassdoor est.)
# 4                       Director, Data Science  111K-181K (Glassdoor est.)
# ...                                        ...                         ...
# 5887       Manufacturing Data Analyst Engineer  42K - 76K (Glassdoor est.)
# 5888                            Data Scientist                          -1
# 5889  Supply Chain Consultant - Data Scientist                          -1
# 5890                     Data Science Engineer                          -1
# 5891      Data Scientist/ Full Stack Developer            65 - 72 Per Hour
#
#       Rating                          Company Name       Location  \
# ...

# %%
def K_remover(a):
  a = a.replace('K','')
  return(a)

# %%
df['Salary Estimate'].apply(K_remover)
# Out:
# 0       111-181 (Glassdoor est.)
# 1       111-181 (Glassdoor est.)
# 2       111-181 (Glassdoor est.)
# 3       111-181 (Glassdoor est.)
# 4       111-181 (Glassdoor est.)
#                   ...
# 5887    42 - 76 (Glassdoor est.)
# 5888                          -1
# 5889                          -1
# 5890                          -1
# 5891            65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Salary Estimate'] = df['Salary Estimate'].apply(K_remover)

# %%
df
# Out:
#                                      Job Title           Salary Estimate  \
# 0                        Senior Data Scientist  111-181 (Glassdoor est.)
# 1            Data Scientist, Product Analytics  111-181 (Glassdoor est.)
# 2                         Data Science Manager  111-181 (Glassdoor est.)
# 3                                 Data Analyst  111-181 (Glassdoor est.)
# 4                       Director, Data Science  111-181 (Glassdoor est.)
# ...                                        ...                       ...
# 5887       Manufacturing Data Analyst Engineer  42 - 76 (Glassdoor est.)
# 5888                            Data Scientist                        -1
# 5889  Supply Chain Consultant - Data Scientist                        -1
# 5890                     Data Science Engineer                        -1
# 5891      Data Scientist/ Full Stack Developer          65 - 72 Per Hour
#
#       Rating                          Company Name       Location  \
# ...

# %%
df = df[df['Salary Estimate'] != '-1']

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# ...

# %%
df = df[~df['Salary Estimate'].str.contains('Per Hour')]

# %%
df.to_csv('df1.csv')

# %%
text = 'I am somayeh'

# %%
text.split()[0]
# Out:
# 'I'

# %%
df['Salary Estimate'].str.split()[0]
# Out:
# ['111-181', '(Glassdoor', 'est.)']

# %%
df['Salary Estimate'].str.split()
# Out:
# 0          [111-181, (Glassdoor, est.)]
# 1          [111-181, (Glassdoor, est.)]
# 2          [111-181, (Glassdoor, est.)]
# 3          [111-181, (Glassdoor, est.)]
# 4          [111-181, (Glassdoor, est.)]
#                      ...
# 5881     [38, -, 64, (Glassdoor, est.)]
# 5882     [47, -, 89, (Glassdoor, est.)]
# 5883    [66, -, 113, (Glassdoor, est.)]
# 5886    [67, -, 111, (Glassdoor, est.)]
# 5887     [42, -, 76, (Glassdoor, est.)]
# Name: Salary Estimate, Length: 5500, dtype: object

# %%
df['min_salary'] = None

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# ...

# %%
df['max_salary'] = None

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# ...

# %%
df['average_salary'] = None

# %%
def min_salary(a):
  a = a.split()[0]
  return(a)

# %%
df['Salary Estimate'].apply(min_salary)
# Out:
# 0       111-181
# 1       111-181
# 2       111-181
# 3       111-181
# 4       111-181
#          ...
# 5881         38
# 5882         47
# 5883         66
# 5886         67
# 5887         42
# Name: Salary Estimate, Length: 5500, dtype: object

# %%
def glass_remover(a):
  a =  a.split()[0]
  return(a)

# %%
df['Salary Estimate'] = df['Salary Estimate'].apply(glass_remover)
# Out:
# <ipython-input-47-63e0ea70448e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary Estimate'] = df['Salary Estimate'].apply(glass_remover)

# %%
df = pd.read_csv('df.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e300d25869ba> in <cell line: 1>()
# ----> 1 df = pd.read_csv('df.csv')
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# ...

# %%
def space_remover(a):
  a = a.replace(' - ','-')
  a = a.replace('-',' ')
  return(a)

# %%
df['Salary Estimate'] = df['Salary Estimate'].apply(space_remover)

# %%
df['Salary Estimate'].apply(min_salary)
# Out:
# 0       111
# 1       111
# 2       111
# 3       111
# 4       111
#        ...
# 5881     38
# 5882     47
# 5883     66
# 5886     67
# 5887     42
# Name: Salary Estimate, Length: 5500, dtype: object

# %%
df['min_salary'] = df['Salary Estimate'].apply(min_salary)

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                Salary Estimate  Rating  \
# 0     111 181 (Glassdoor est.)     3.5
# 1     111 181 (Glassdoor est.)     4.5
# 2     111 181 (Glassdoor est.)    -1.0
# 3     111 181 (Glassdoor est.)     3.4
# 4     111 181 (Glassdoor est.)     3.4
# ...                        ...     ...
# ...

# %%
def max_salary(a):
  a = a.split()[1]
  return(a)

# %%
df['Salary Estimate'].apply(max_salary)
# Out:
# 0       181
# 1       181
# 2       181
# 3       181
# 4       181
#        ...
# 5881     64
# 5882     89
# 5883    113
# 5886    111
# 5887     76
# Name: Salary Estimate, Length: 5500, dtype: object

# %%
df['max_salary'] = df['Salary Estimate'].apply(max_salary)

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                Salary Estimate  Rating  \
# 0     111 181 (Glassdoor est.)     3.5
# 1     111 181 (Glassdoor est.)     4.5
# 2     111 181 (Glassdoor est.)    -1.0
# 3     111 181 (Glassdoor est.)     3.4
# 4     111 181 (Glassdoor est.)     3.4
# ...                        ...     ...
# ...

# %%
df['average_salary'] = None

# %%
def average_salary(a,b):
  c = (a+b)/2
  return(c)

# %%
df['average_salary'] = average_salary(df['min_salary'],df['max_salary'])

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                Salary Estimate  Rating  \
# 0     111 181 (Glassdoor est.)     3.5
# 1     111 181 (Glassdoor est.)     4.5
# 2     111 181 (Glassdoor est.)    -1.0
# 3     111 181 (Glassdoor est.)     3.4
# 4     111 181 (Glassdoor est.)     3.4
# ...                        ...     ...
# ...

# %%
def make_int(a):
  a = int(a)
  return(a)

# %%
df['min_salary'] = df['min_salary'].apply(make_int)

# %%
df['max_salary'].apply(make_int)
# Out:
# 0       181
# 1       181
# 2       181
# 3       181
# 4       181
#        ...
# 5881     64
# 5882     89
# 5883    113
# 5886    111
# 5887     76
# Name: max_salary, Length: 5500, dtype: int64

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                Salary Estimate  Rating  \
# 0     111 181 (Glassdoor est.)     3.5
# 1     111 181 (Glassdoor est.)     4.5
# 2     111 181 (Glassdoor est.)    -1.0
# 3     111 181 (Glassdoor est.)     3.4
# 4     111 181 (Glassdoor est.)     3.4
# ...                        ...     ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5500 entries, 0 to 5887
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5500 non-null   object
#  1   Salary Estimate    5500 non-null   object
#  2   Rating             5500 non-null   float64
#  3   Company Name       5500 non-null   object
#  4   Location           5500 non-null   object
#  5   Size               5500 non-null   object
#  6   Founded            5500 non-null   object
#  7   Type of ownership  5500 non-null   object
#  8   Industry           5500 non-null   object
#  9   Sector             5500 non-null   object
#  10  Revenue            5500 non-null   object
#  11  min_salary         5500 non-null   int64
#  12  max_salary         5500 non-null   object
#  13  average_salary     0 non-null      object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 773.6+ KB

# %%
df[df['max_salary'] == '250(Employer']
# Out:
#                                               Job Title  \
# 2980                      Diagnostic Research Scientist
# 2981                                       Data Analyst
# 2982                             Senior HR Data Analyst
# 2983    Machine Learning Engineer, TikTok Ads Integrity
# 2984                                       Data Analyst
# 2985  Quantum Data Scientist (Industrial-Process sec...
# 2986                                Staff Data Engineer
# 2987                              Senior Data Scientist
# 2988  Marketing Data Scientist, gTech Professional S...
# 2989         Data Scientist, Ad Platforms/Data Insights
# 2990                                 Research Scientist
# 2991         Sr. Data Scientist - Platform Manipulation
# 2992                   Data Scientist, Machine Learning
# 2993                             Data Science Developer
# 2994          Data Scientist Machine Learning at Google
# 2995                                 NLP Data Scientist
# ...

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                Salary Estimate  Rating  \
# 0     111 181 (Glassdoor est.)     3.5
# 1     111 181 (Glassdoor est.)     4.5
# 2     111 181 (Glassdoor est.)    -1.0
# 3     111 181 (Glassdoor est.)     3.4
# 4     111 181 (Glassdoor est.)     3.4
# ...                        ...     ...
# ...

# %%
def max_salary_space(a):
  a = a.replace('(E',' (E)')
  a = a.split()[0]
  return(a)

# %%
df['max_salary'].apply(max_salary_space)
# Out:
# 0       181
# 1       181
# 2       181
# 3       181
# 4       181
#        ...
# 5881     64
# 5882     89
# 5883    113
# 5886    111
# 5887     76
# Name: max_salary, Length: 5500, dtype: object

# %%
df['max_salary'] = df['max_salary'].apply(max_salary_space)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5500 entries, 0 to 5887
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5500 non-null   object
#  1   Salary Estimate    5500 non-null   object
#  2   Rating             5500 non-null   float64
#  3   Company Name       5500 non-null   object
#  4   Location           5500 non-null   object
#  5   Size               5500 non-null   object
#  6   Founded            5500 non-null   object
#  7   Type of ownership  5500 non-null   object
#  8   Industry           5500 non-null   object
#  9   Sector             5500 non-null   object
#  10  Revenue            5500 non-null   object
#  11  min_salary         5500 non-null   int64
#  12  max_salary         5500 non-null   int64
#  13  average_salary     0 non-null      object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 773.6+ KB

# %%
df['max_salary'] = df['max_salary'].apply(make_int)

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                Salary Estimate  Rating  \
# 0     111 181 (Glassdoor est.)     3.5
# 1     111 181 (Glassdoor est.)     4.5
# 2     111 181 (Glassdoor est.)    -1.0
# 3     111 181 (Glassdoor est.)     3.4
# 4     111 181 (Glassdoor est.)     3.4
# ...                        ...     ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5500 entries, 0 to 5887
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5500 non-null   object
#  1   Salary Estimate    5500 non-null   object
#  2   Rating             5500 non-null   float64
#  3   Company Name       5500 non-null   object
#  4   Location           5500 non-null   object
#  5   Size               5500 non-null   object
#  6   Founded            5500 non-null   object
#  7   Type of ownership  5500 non-null   object
#  8   Industry           5500 non-null   object
#  9   Sector             5500 non-null   object
#  10  Revenue            5500 non-null   object
#  11  min_salary         5500 non-null   int64
#  12  max_salary         5500 non-null   int64
#  13  average_salary     5500 non-null   float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 773.6+ KB
