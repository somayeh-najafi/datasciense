# %% [markdown]
# <a href="https://colab.research.google.com/github/somayeh-najafi/datasciense/blob/main/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d83f8907-fb4d-42ea-92c7-11738127ac01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d83f8907-fb4d-42ea-92c7-11738127ac01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('df.csv')

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5892 entries, 0 to 5891
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5892 non-null   object
#  1   Salary Estimate    5892 non-null   object
#  2   Rating             5892 non-null   float64
#  3   Company Name       5892 non-null   object
#  4   Location           5892 non-null   object
#  5   Size               5892 non-null   object
#  6   Founded            5892 non-null   object
#  7   Type of ownership  5892 non-null   object
#  8   Industry           5892 non-null   object
#  9   Sector             5892 non-null   object
#  10  Revenue            5892 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 506.5+ KB

# %%
df.head()
# Out:
#                            Job Title               Salary Estimate  Rating  \
# 0              Senior Data Scientist  $111K-$181K (Glassdoor est.)     3.5
# 1  Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)     4.5
# 2               Data Science Manager  $111K-$181K (Glassdoor est.)    -1.0
# 3                       Data Analyst  $111K-$181K (Glassdoor est.)     3.4
# 4             Director, Data Science  $111K-$181K (Glassdoor est.)     3.4
#
#                       Company Name       Location                    Size  \
# 0                      Hopper\n3.5   New York, NY   501 to 1000 employees
# 1                     Noom US\n4.5   New York, NY  1001 to 5000 employees
# 2                         Decode_M   New York, NY       1 to 50 employees
# 3            Sapphire Digital\n3.4  Lyndhurst, NJ    201 to 500 employees
# 4  United Entertainment Group\n3.4   New York, NY     51 to 200 employees
#
#   Founded  Type of ownership                   Industry  \
# ...

# %%
df.tail()
# Out:
#                                      Job Title               Salary Estimate  \
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
#       Rating                          Company Name       Location  \
# 5887     3.6                      Hose Master\n3.6     Euclid, OH
# 5888     4.9                 Bluetree Network\n4.9    Madison, WI
# 5889     4.0  Kimberly-Clark Corporation, LLC\n4.0     Neenah, WI
# 5890     4.0            AE Business Solutions\n4.0    Madison, WI
# 5891     3.7                           Epitec\n3.7  Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# ...

# %%
df.size
# Out:
# 64812

# %%
df.describe()
# Out:
#             Rating
# count  5892.000000
# mean      3.244603
# std       1.660970
# min      -1.000000
# 25%       3.300000
# 50%       3.800000
# 75%       4.100000
# max       5.000000

# %%
df['Founded']
# Out:
# 0       2007
# 1       2008
# 2         -1
# 3       2019
# 4       2007
#         ...
# 5887    1982
# 5888      -1
# 5889    1872
# 5890    1949
# 5891    1978
# Name: Founded, Length: 5892, dtype: object

# %%
df['Job Title']
# Out:
# 0                          Senior Data Scientist
# 1              Data Scientist, Product Analytics
# 2                           Data Science Manager
# 3                                   Data Analyst
# 4                         Director, Data Science
#                           ...
# 5887         Manufacturing Data Analyst Engineer
# 5888                              Data Scientist
# 5889    Supply Chain Consultant - Data Scientist
# 5890                       Data Science Engineer
# 5891        Data Scientist/ Full Stack Developer
# Name: Job Title, Length: 5892, dtype: object

# %%
df['Industry'].value_counts()
# Out:
# -1                                 863
# IT Services                        574
# Biotech & Pharmaceuticals          449
# Staffing & Outsourcing             426
# Computer Hardware & Software       358
#                                   ...
# Self-Storage Services                1
# Sporting Goods Stores                1
# Museums, Zoos & Amusement Parks      1
# Metals Brokers                       1
# Charter Air Travel                   1
# Name: Industry, Length: 118, dtype: int64

# %%
df.drop('Founded',axis=1)
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df = df.drop('Founded',axis=1)

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df['Rating'].value_counts().plot.hist(bins=4)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Rating'].plot.hist(bins=6,color='black',edgecolor='cyan')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Type of ownership'].value_counts().plot(kind='bar',color='cyan')
# Out:
# <Axes: >

# %%
list1 = ['ali','james',2,5,45,5]

# %%
list1
# Out:
# ['ali', 'james', 2, 5, 45, 5]

# %%
list1[-2]
# Out:
# 45

# %%
list1[2]
# Out:
# 2

# %%
list1.append('ali')

# %%
list1
# Out:
# ['ali', 'james', 2, 5, 45, 5, 'ali']

# %%
set1 = {1,3,1,'ali'}

# %%
set1
# Out:
# {1, 3, 'ali'}

# %%
set1.add('james')

# %%
set1
# Out:
# {1, 3, 'ali', 'james'}

# %%
set1.add(2)

# %%
set1
# Out:
# {1, 2, 3, 'ali', 'james'}

# %%
set2 = set(list1)

# %%
set2
# Out:
# {2, 45, 5, 'ali', 'james'}

# %%
tuple1 = (1,2,3,1)

# %%
tuple1
# Out:
# (1, 2, 3, 1)

# %%
tuple1.count(1)
# Out:
# 2

# %%
dict1 = {'key1':'value1','key2':'value2'}

# %%
dict1
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
max(tuple1)
# Out:
# 3

# %%
min(tuple1)
# Out:
# 1

# %%
sum(tuple1)
# Out:
# 7

# %%
int(3243.34342)
# Out:
# 3243

# %%
help(tuple1.count)
# Out:
# Help on built-in function count:
#
# count(value, /) method of builtins.tuple instance
#     Return number of occurrences of value.

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df['Rating']
# Out:
# 0       3.5
# 1       4.5
# 2      -1.0
# 3       3.4
# 4       3.4
#        ...
# 5887    3.6
# 5888    4.9
# 5889    4.0
# 5890    4.0
# 5891    3.7
# Name: Rating, Length: 5892, dtype: float64

# %%
df['Rating'][5891]
# Out:
# 3.7

# %%
int(df['Rating'][5891])
# Out:
# 3

# %%
df['Rating'].apply(int)
# Out:
# 0       3
# 1       4
# 2      -1
# 3       3
# 4       3
#        ..
# 5887    3
# 5888    4
# 5889    4
# 5890    4
# 5891    3
# Name: Rating, Length: 5892, dtype: int64

# %%
df['Salary Estimate']
# Out:
# 0       $111K-$181K (Glassdoor est.)
# 1       $111K-$181K (Glassdoor est.)
# 2       $111K-$181K (Glassdoor est.)
# 3       $111K-$181K (Glassdoor est.)
# 4       $111K-$181K (Glassdoor est.)
#                     ...
# 5887    $42K - $76K (Glassdoor est.)
# 5888                              -1
# 5889                              -1
# 5890                              -1
# 5891              $65 - $72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Rating'].apply(int)[2]
# Out:
# -1

# %%
df['Salary Estimate'][0]
# Out:
# '$111K-$181K (Glassdoor est.)'

# %%
df['Salary Estimate'][0].replace('$','')
# Out:
# '111K-181K (Glassdoor est.)'

# %%
from os import replace
df['Salary Estimate'].apply(replace('$',''))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-80-ddb16a5db3b5> in <cell line: 2>()
#       1 from os import replace
# ----> 2 df['Salary Estimate'].apply(replace('$',''))
#
# FileNotFoundError: [Errno 2] No such file or directory: '$' -> ''

# %%
df['Salary Estimate'].str.replace('$','')
# Out:
# <ipython-input-81-69f156615c04>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Salary Estimate'].str.replace('$','')
# 0       111K-181K (Glassdoor est.)
# 1       111K-181K (Glassdoor est.)
# 2       111K-181K (Glassdoor est.)
# 3       111K-181K (Glassdoor est.)
# 4       111K-181K (Glassdoor est.)
#                    ...
# 5887    42K - 76K (Glassdoor est.)
# 5888                            -1
# 5889                            -1
# 5890                            -1
# 5891              65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df = df['Salary Estimate'].str.replace('$','')
# Out:
# <ipython-input-82-9e73751c6f98>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df = df['Salary Estimate'].str.replace('$','')

# %%
df
# Out:
# 0       111K-181K (Glassdoor est.)
# 1       111K-181K (Glassdoor est.)
# 2       111K-181K (Glassdoor est.)
# 3       111K-181K (Glassdoor est.)
# 4       111K-181K (Glassdoor est.)
#                    ...
# 5887    42K - 76K (Glassdoor est.)
# 5888                            -1
# 5889                            -1
# 5890                            -1
# 5891              65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df = pd.read_csv('df.csv')

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df.drop('Founded',axis=1)
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df['Salary Estimate'].str.replace('$','')
# Out:
# <ipython-input-89-69f156615c04>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Salary Estimate'].str.replace('$','')
# 0       111K-181K (Glassdoor est.)
# 1       111K-181K (Glassdoor est.)
# 2       111K-181K (Glassdoor est.)
# 3       111K-181K (Glassdoor est.)
# 4       111K-181K (Glassdoor est.)
#                    ...
# 5887    42K - 76K (Glassdoor est.)
# 5888                            -1
# 5889                            -1
# 5890                            -1
# 5891              65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Salary Estimate'] = df['Salary Estimate'].str.replace('$','')
# Out:
# <ipython-input-90-46d0a6f001d2>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Salary Estimate'] = df['Salary Estimate'].str.replace('$','')

# %%
df
# Out:
#                                      Job Title             Salary Estimate  \
# 0                        Senior Data Scientist  111K-181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  111K-181K (Glassdoor est.)
# 2                         Data Science Manager  111K-181K (Glassdoor est.)
# 3                                 Data Analyst  111K-181K (Glassdoor est.)
# 4                       Director, Data Science  111K-181K (Glassdoor est.)
# ...                                        ...                         ...
# 5887       Manufacturing Data Analyst Engineer  42K - 76K (Glassdoor est.)
# 5888                            Data Scientist                          -1
# 5889  Supply Chain Consultant - Data Scientist                          -1
# 5890                     Data Science Engineer                          -1
# 5891      Data Scientist/ Full Stack Developer            65 - 72 Per Hour
#
#       Rating                          Company Name       Location  \
# ...

# %%
df['Salary Estimate'].str.replace('K','')
# Out:
# 0       111-181 (Glassdoor est.)
# 1       111-181 (Glassdoor est.)
# 2       111-181 (Glassdoor est.)
# 3       111-181 (Glassdoor est.)
# 4       111-181 (Glassdoor est.)
#                   ...
# 5887    42 - 76 (Glassdoor est.)
# 5888                          -1
# 5889                          -1
# 5890                          -1
# 5891            65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Salary Estimate'] = df['Salary Estimate'].str.replace('K','')

# %%
df
# Out:
#                                      Job Title           Salary Estimate  \
# 0                        Senior Data Scientist  111-181 (Glassdoor est.)
# 1            Data Scientist, Product Analytics  111-181 (Glassdoor est.)
# 2                         Data Science Manager  111-181 (Glassdoor est.)
# 3                                 Data Analyst  111-181 (Glassdoor est.)
# 4                       Director, Data Science  111-181 (Glassdoor est.)
# ...                                        ...                       ...
# 5887       Manufacturing Data Analyst Engineer  42 - 76 (Glassdoor est.)
# 5888                            Data Scientist                        -1
# 5889  Supply Chain Consultant - Data Scientist                        -1
# 5890                     Data Science Engineer                        -1
# 5891      Data Scientist/ Full Stack Developer          65 - 72 Per Hour
#
#       Rating                          Company Name       Location  \
# ...

# %%
df['Salary Estimate'].str.replace('(Glassdoor est.)','')
# Out:
# <ipython-input-95-76461d1065ae>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary Estimate'].str.replace('(Glassdoor est.)','')
# 0             111-181 ()
# 1             111-181 ()
# 2             111-181 ()
# 3             111-181 ()
# 4             111-181 ()
#               ...
# 5887          42 - 76 ()
# 5888                  -1
# 5889                  -1
# 5890                  -1
# 5891    65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Salary Estimate'] = df['Salary Estimate'].str.replace('(Glassdoor est.)','')
# Out:
# <ipython-input-96-482728cac215>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary Estimate'] = df['Salary Estimate'].str.replace('(Glassdoor est.)','')

# %%
df
# Out:
#                                      Job Title   Salary Estimate  Rating  \
# 0                        Senior Data Scientist        111-181 ()     3.5
# 1            Data Scientist, Product Analytics        111-181 ()     4.5
# 2                         Data Science Manager        111-181 ()    -1.0
# 3                                 Data Analyst        111-181 ()     3.4
# 4                       Director, Data Science        111-181 ()     3.4
# ...                                        ...               ...     ...
# 5887       Manufacturing Data Analyst Engineer        42 - 76 ()     3.6
# 5888                            Data Scientist                -1     4.9
# 5889  Supply Chain Consultant - Data Scientist                -1     4.0
# 5890                     Data Science Engineer                -1     4.0
# 5891      Data Scientist/ Full Stack Developer  65 - 72 Per Hour     3.7
#
#                               Company Name       Location  \
# ...

# %%
df['Salary Estimate'].str.replace('/(/)','')
# Out:
# <ipython-input-98-f4fcfe7d6c82>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary Estimate'].str.replace('/(/)','')
# 0             111-181 ()
# 1             111-181 ()
# 2             111-181 ()
# 3             111-181 ()
# 4             111-181 ()
#               ...
# 5887          42 - 76 ()
# 5888                  -1
# 5889                  -1
# 5890                  -1
# 5891    65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Salary Estimate'].str.replace('\(\)','')
# Out:
# <ipython-input-100-789d12ddb301>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary Estimate'].str.replace('\(\)','')
# 0               111-181
# 1               111-181
# 2               111-181
# 3               111-181
# 4               111-181
#               ...
# 5887            42 - 76
# 5888                  -1
# 5889                  -1
# 5890                  -1
# 5891    65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Salary Estimate'] = df['Salary Estimate'].str.replace('\(\)','')
# Out:
# <ipython-input-101-74804ea6ba6b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary Estimate'] = df['Salary Estimate'].str.replace('\(\)','')

# %%
df
# Out:
#                                      Job Title   Salary Estimate  Rating  \
# 0                        Senior Data Scientist          111-181      3.5
# 1            Data Scientist, Product Analytics          111-181      4.5
# 2                         Data Science Manager          111-181     -1.0
# 3                                 Data Analyst          111-181      3.4
# 4                       Director, Data Science          111-181      3.4
# ...                                        ...               ...     ...
# 5887       Manufacturing Data Analyst Engineer          42 - 76      3.6
# 5888                            Data Scientist                -1     4.9
# 5889  Supply Chain Consultant - Data Scientist                -1     4.0
# 5890                     Data Science Engineer                -1     4.0
# 5891      Data Scientist/ Full Stack Developer  65 - 72 Per Hour     3.7
#
#                               Company Name       Location  \
# ...

# %%
name = "I'm somayeh najafi"

# %%
name
# Out:
# "I'm somayeh najafi"

# %%
print("I'm" in name)
# Out:
# True

# %%
print('I'm' in name)
# Out:
#   File "<ipython-input-106-ee34e3c55b25>", line 1
#     print('I'm' in name)
#               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f3ca872-5724-4688-84d4-479d537e3348" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f3ca872-5724-4688-84d4-479d537e3348">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('df.csv')

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.10/dist-packages/pandas/__init__.py'>

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
def dollar_remover(a):
  a=a.replace('$','')
  return (a)

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df['Salary Estimate']
# Out:
# 0       $111K-$181K (Glassdoor est.)
# 1       $111K-$181K (Glassdoor est.)
# 2       $111K-$181K (Glassdoor est.)
# 3       $111K-$181K (Glassdoor est.)
# 4       $111K-$181K (Glassdoor est.)
#                     ...
# 5887    $42K - $76K (Glassdoor est.)
# 5888                              -1
# 5889                              -1
# 5890                              -1
# 5891              $65 - $72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Salary Estimate'].apply(dollar_remover)
# Out:
# 0       111K-181K (Glassdoor est.)
# 1       111K-181K (Glassdoor est.)
# 2       111K-181K (Glassdoor est.)
# 3       111K-181K (Glassdoor est.)
# 4       111K-181K (Glassdoor est.)
#                    ...
# 5887    42K - 76K (Glassdoor est.)
# 5888                            -1
# 5889                            -1
# 5890                            -1
# 5891              65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Salary Estimate'] = df['Salary Estimate'].apply(dollar_remover)

# %%
df['Salary Estimate']
# Out:
# 0       111K-181K (Glassdoor est.)
# 1       111K-181K (Glassdoor est.)
# 2       111K-181K (Glassdoor est.)
# 3       111K-181K (Glassdoor est.)
# 4       111K-181K (Glassdoor est.)
#                    ...
# 5887    42K - 76K (Glassdoor est.)
# 5888                            -1
# 5889                            -1
# 5890                            -1
# 5891              65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
def k_remover(a):
  a=a.replace('K','')
  return(a)

# %%
df['Salary Estimate'].apply(k_remover)
# Out:
# 0       111-181 (Glassdoor est.)
# 1       111-181 (Glassdoor est.)
# 2       111-181 (Glassdoor est.)
# 3       111-181 (Glassdoor est.)
# 4       111-181 (Glassdoor est.)
#                   ...
# 5887    42 - 76 (Glassdoor est.)
# 5888                          -1
# 5889                          -1
# 5890                          -1
# 5891            65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Salary Estimate']=df['Salary Estimate'].apply(k_remover)

# %%
df['Salary Estimate']
# Out:
# 0       111-181 (Glassdoor est.)
# 1       111-181 (Glassdoor est.)
# 2       111-181 (Glassdoor est.)
# 3       111-181 (Glassdoor est.)
# 4       111-181 (Glassdoor est.)
#                   ...
# 5887    42 - 76 (Glassdoor est.)
# 5888                          -1
# 5889                          -1
# 5890                          -1
# 5891            65 - 72 Per Hour
# Name: Salary Estimate, Length: 5892, dtype: object

# %%
df['Salary Estimate'] != '-1'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5887     True
# 5888    False
# 5889    False
# 5890    False
# 5891     True
# Name: Salary Estimate, Length: 5892, dtype: bool

# %%
df[df['Salary Estimate'] != '-1']
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# ...

# %%
df = df[df['Salary Estimate'] != '-1']

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# ...

# %%
~df['Salary Estimate'].str.contains('Per Hour')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5882     True
# 5883     True
# 5886     True
# 5887     True
# 5891    False
# Name: Salary Estimate, Length: 5526, dtype: bool

# %%
df[~df['Salary Estimate'].str.contains('Per Hour')]
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# ...

# %%
df = df[~df['Salary Estimate'].str.contains('Per Hour')]

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# ...

# %%
text1 = 'my naame is somayeh'

# %%
text1.split()
# Out:
# ['my', 'naame', 'is', 'somayeh']

# %%
text1.split()[2]
# Out:
# 'is'

# %%
df['min_salary']= None
# Out:
# <ipython-input-37-ae3ab82560c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_salary']= None

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# ...

# %%
df['min_salary'][0] = df['Salary Estimate'][0].split()[0]
# Out:
# <ipython-input-40-d7255dc6b848>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_salary'][0] = df['Salary Estimate'][0].split()[0]

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                 Salary Estimate  Rating  \
# 0      111-181 (Glassdoor est.)     3.5
# 1      111-181 (Glassdoor est.)     4.5
# 2      111-181 (Glassdoor est.)    -1.0
# 3      111-181 (Glassdoor est.)     3.4
# 4      111-181 (Glassdoor est.)     3.4
# ...                         ...     ...
# ...

# %%
df['Salary Estimate'][0].split()[0]
# Out:
# '111-181'

# %%
df['Salary Estimate'][0].split()
# Out:
# ['111-181', '(Glassdoor', 'est.)']

# %%
def min_salary(a):
  a = a.split()[0]
  return(a)

# %%
df['Salary Estimate'].apply(glass_split)
# Out:
# 0       111-181
# 1       111-181
# 2       111-181
# 3       111-181
# 4       111-181
#          ...
# 5881         38
# 5882         47
# 5883         66
# 5886         67
# 5887         42
# Name: Salary Estimate, Length: 5500, dtype: object

# %%
def space_align(a):
  a=a.replace(' - ','-')
  a=a.replace('-',' - ')
  return(a)

# %%
df['Salary Estimate'] = df['Salary Estimate'].apply(space_align)
# Out:
# <ipython-input-52-1b09648ddb35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary Estimate'] = df['Salary Estimate'].apply(space_align)

# %%
df['min_salary'] = df['Salary Estimate'].apply(min_salary)
# Out:
# <ipython-input-54-331f309c2500>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_salary'] = df['Salary Estimate'].apply(min_salary)

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                  Salary Estimate  Rating  \
# 0     111 - 181 (Glassdoor est.)     3.5
# 1     111 - 181 (Glassdoor est.)     4.5
# 2     111 - 181 (Glassdoor est.)    -1.0
# 3     111 - 181 (Glassdoor est.)     3.4
# 4     111 - 181 (Glassdoor est.)     3.4
# ...

# %%
def max_salary(a):
  a = a.split()[2]

  return(a)

# %%
df['Salary Estimate'].apply(max_salary)
# Out:
# 0       181
# 1       181
# 2       181
# 3       181
# 4       181
#        ...
# 5881     64
# 5882     89
# 5883    113
# 5886    111
# 5887     76
# Name: Salary Estimate, Length: 5500, dtype: object

# %%
df['max_salary'] = df['Salary Estimate'].apply(max_salary)
# Out:
# <ipython-input-61-bdec3b7801f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_salary'] = df['Salary Estimate'].apply(max_salary)

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                  Salary Estimate  Rating  \
# 0     111 - 181 (Glassdoor est.)     3.5
# 1     111 - 181 (Glassdoor est.)     4.5
# 2     111 - 181 (Glassdoor est.)    -1.0
# 3     111 - 181 (Glassdoor est.)     3.4
# 4     111 - 181 (Glassdoor est.)     3.4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5500 entries, 0 to 5887
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          5500 non-null   object
#  1   Salary Estimate    5500 non-null   object
#  2   Rating             5500 non-null   float64
#  3   Company Name       5500 non-null   object
#  4   Location           5500 non-null   object
#  5   Size               5500 non-null   object
#  6   Founded            5500 non-null   object
#  7   Type of ownership  5500 non-null   object
#  8   Industry           5500 non-null   object
#  9   Sector             5500 non-null   object
#  10  Revenue            5500 non-null   object
#  11  min_salary         5500 non-null   object
#  12  max_salary         5500 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 730.6+ KB
