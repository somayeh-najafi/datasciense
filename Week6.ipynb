# %% [markdown]
# <a href="https://colab.research.google.com/github/somayeh-najafi/datasciense/blob/main/Week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4f997fe1-0aaf-42ae-8468-8fe4ac4c2bd7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f997fe1-0aaf-42ae-8468-8fe4ac4c2bd7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('df_w5.csv')

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                              Senior Data Scientist
# 1              1                  Data Scientist, Product Analytics
# 2              3                                       Data Analyst
# 3              4                             Director, Data Science
# 4              5                                     Data Scientist
# ...          ...                                                ...
# 4886        5881                              Information Scientist
# 4887        5882              Supervisory Research Health Scientist
# 4888        5883                  Senior SAS Programmer (Scientist)
# 4889        5886  Senior Data Analyst - Product Analytics (open ...
# 4890        5887                Manufacturing Data Analyst Engineer
#
#                                  Salary Estimate  Rating  \
# 0     ['111', '-', '181', '(Glassdoor', 'est.)']     3.5
# ...

# %%
df['Job Title'].value_counts()
# Out:
# Data Scientist                                                   530
# Data Analyst                                                     296
# Data Engineer                                                    267
# Senior Data Scientist                                            117
# Machine Learning Engineer                                         55
#                                                                 ...
# Data Scientist - Top Secret w/ SCI Eligibility                     1
# Business Intelligence Analyst I                                    1
# Business Intelligence Analyst Senior (Chief Financial Office)      1
# Business Intelligence Analyst III - Credit Card                    1
# Manufacturing Data Analyst Engineer                                1
# Name: Job Title, Length: 2552, dtype: int64

# %%
def title_organizer(x):
  x = x.lower()
  if ('data scientist' in x) or ('data science' in x):
    return 'Data Scientist'
  elif 'analyst' in x:
    return 'Data Analyst'
  elif 'data engineer' in x:
    return 'Data Engineer'
  elif 'deep learning' in x:
    return 'Deep Learning Engineer'
  elif 'machine learning' in x:
    return 'Machine Learning Engineer'
  elif 'director' in x:
    return 'Director'
  elif 'manager' in x:
    return 'Manager'
  elif ('researcher' in x) or ('research' in x):
    return 'Researcher'
  else:
    return 'Others'

# %%
df['Job Title'] = df['Job Title'].apply(title_organizer)

# %%
set(df['Job Title'])
# Out:
# {'Data Analyst',
#  'Data Engineer',
#  'Data Scientist',
#  'Deep Learning Engineer',
#  'Director',
#  'Machine Learning Engineer',
#  'Manager',
#  'Others',
#  'Researcher'}

# %%
df
# Out:
#       Unnamed: 0       Job Title                             Salary Estimate  \
# 0              0  Data Scientist  ['111', '-', '181', '(Glassdoor', 'est.)']
# 1              1  Data Scientist  ['111', '-', '181', '(Glassdoor', 'est.)']
# 2              3    Data Analyst  ['111', '-', '181', '(Glassdoor', 'est.)']
# 3              4  Data Scientist  ['111', '-', '181', '(Glassdoor', 'est.)']
# 4              5  Data Scientist  ['111', '-', '181', '(Glassdoor', 'est.)']
# ...          ...             ...                                         ...
# 4886        5881          Others    ['38', '-', '64', '(Glassdoor', 'est.)']
# 4887        5882      Researcher    ['47', '-', '89', '(Glassdoor', 'est.)']
# 4888        5883          Others   ['66', '-', '113', '(Glassdoor', 'est.)']
# 4889        5886    Data Analyst   ['67', '-', '111', '(Glassdoor', 'est.)']
# 4890        5887    Data Analyst    ['42', '-', '76', '(Glassdoor', 'est.)']
#
# ...

# %%
df1 = df

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Rating', 'Company Name',
#        'Location', 'Size', 'Founded', 'Type of ownership', 'Industry',
#        'Sector', 'Revenue', 'min_salary', 'max_salary', 'average_salary',
#        'state'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0','Salary Estimate','Company Name',
       'Location', 'Size', 'Founded', 'Type of ownership', 'Industry',
       'Sector', 'Revenue', 'min_salary', 'max_salary'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-69e91fc314e6> in <cell line: 1>()
# ----> 1 df.drop(columns=['Unnamed: 0','Salary Estimate','Company Name',
#       2        'Location', 'Size', 'Founded', 'Type of ownership', 'Industry',
#       3        'Sector', 'Revenue', 'min_salary', 'max_salary'], inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# ...

# %%
df
# Out:
#            Job Title  Rating  average_salary state
# 0     Data Scientist     3.5           146.0    NY
# 1     Data Scientist     4.5           146.0    NY
# 2       Data Analyst     3.4           146.0    NJ
# 3     Data Scientist     3.4           146.0    NY
# 4     Data Scientist     2.9           146.0    NY
# ...              ...     ...             ...   ...
# 4886          Others     3.2            51.0    OH
# 4887      Researcher     4.2            68.0    OH
# 4888          Others     4.0            89.5    OH
# 4889    Data Analyst     4.0            89.0    OH
# 4890    Data Analyst     3.6            59.0    OH
#
# [4891 rows x 4 columns]

# %%
df['average_salary'].hist(bins=10)
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.displot(x='average_salary',data=df,bins=10)

# %%
sns.countplot(x='Job Title', data=df)
# Out:
# <Axes: xlabel='Job Title', ylabel='count'>

# %%
import matplotlib.pylab as plt

# %%
sns.countplot(x='Job Title', data=df)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Data Scientist'),
#   Text(1, 0, 'Data Analyst'),
#   Text(2, 0, 'Researcher'),
#   Text(3, 0, 'Others'),
#   Text(4, 0, 'Data Engineer'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Machine Learning Engineer'),
#   Text(7, 0, 'Director'),
#   Text(8, 0, 'Deep Learning Engineer')])

# %%
sns.boxplot(x='Job Title',y='average_salary', data=df)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Data Scientist'),
#   Text(1, 0, 'Data Analyst'),
#   Text(2, 0, 'Researcher'),
#   Text(3, 0, 'Others'),
#   Text(4, 0, 'Data Engineer'),
#   Text(5, 0, 'Manager'),
#   Text(6, 0, 'Machine Learning Engineer'),
#   Text(7, 0, 'Director'),
#   Text(8, 0, 'Deep Learning Engineer')])
